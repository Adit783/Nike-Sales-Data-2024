# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\aadig\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\aadig\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\aadig\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\aadig\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
# ...

# %%
import numpy as np

# %%
dfi1 = pd.read_excel("C:\\Users\\aadig\\OneDrive\\Desktop\\Nuel\\nike_sales_data_features.xlsx", sheet_name = 'Sheet1', engine = "openpyxl")
dfi2 = pd.read_excel("C:\\Users\\aadig\\OneDrive\\Desktop\\Nuel\\holiday_counts1.xlsx", sheet_name = 'Sheet1', engine = "openpyxl")

# %%
merged_ds11 = pd.merge(dfi1,dfi2, on=['Country', 'Month'], how='inner')
merged_ds11
# Out:
#          Month      Country Main_Category Sub_Category       Product_Line  \
# 0      January        India     Equipment  Accessories               Hats
# 1      October        India       Apparel         Tops        Tech Fleece
# 2     December        China      Footwear      Cricket      Vapor Cricket
# 3          May        China     Equipment        Socks  Performance Socks
# 4      October        Japan       Apparel  Performance            Dri-FIT
# ..         ...          ...           ...          ...                ...
# 782  September        Japan       Apparel         Tops        Tech Fleece
# 783    October        India     Equipment  Accessories               Hats
# 784     August        Japan      Footwear     Football     Phantom Vision
# 785        May  South Korea     Equipment        Socks         Crew Socks
# 786   December        Japan      Footwear      Cricket      Vapor Cricket
#
#     Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  \
# ...

# %%
# Holiday Sales Boost (10% revenue boost per holiday)
merged_ds11['Holiday_Sales_Estimate'] = merged_ds11['Revenue_USD'] * (0.1 * merged_ds11['HolidayCount'])

# %%
merged_ds11.to_excel("C:\\Users\\aadig\\OneDrive\\Desktop\\Nuel\\nike_sales_data_features_final.xlsx", index = False, engine = 'openpyxl')
